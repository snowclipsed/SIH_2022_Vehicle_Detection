# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('test_images/imtest1.jpeg'))

# %%
import time

# %%
# %run detect.py --classes 0 --weights runs/train/exp12/weights/best.pt --exist-ok --conf-thres 0.5 --source 0
# Out:
# detect: weights=['runs/train/exp12/weights/best.pt'], source=0, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5  2022-7-30 torch 1.12.1+cpu CPU
# Fusing layers...
# Model Summary: 308 layers, 21053802 parameters, 0 gradients, 50.3 GFLOPs
# 1/1: 0...  success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 2
# 0: 480x640 1
# 0: 480x640 2
# ...
